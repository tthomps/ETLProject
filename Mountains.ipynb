# %% [markdown]
# ## Dataset CSV

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import random
# Import API key
# from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ##  CREATE FIRST DATAFRAME

# %%
df_mountain = pd.read_csv('14er.csv', encoding='latin')



print ("df_mountain")
# Sports_athlete_df.set_index('Rank').head()
display(df_mountain.set_index('ID').head(5).style.set_properties(**{"background-color":"green","color":"black","border-color":"white"}))
# Out:
# df_mountain
# <style  type="text/css" >
#     #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col0 {
#             background-color:  green;
#             color:  black;
#             border-color:  white;
#         }    #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col1 {
#             background-color:  green;
#             color:  black;
#             border-color:  white;
#         }    #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col2 {
#             background-color:  green;
#             color:  black;
#             border-color:  white;
#         }    #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col3 {
#             background-color:  green;
#             color:  black;
#             border-color:  white;
#         }    #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col4 {
#             background-color:  green;
#             color:  black;
#             border-color:  white;
#         }    #T_483e0070_c689_11e9_a5da_2cf0ee134bbcrow0_col5 {
#             background-color:  green;
# ...

# %%
# %%bash
#
# head -5 14er.csv
# Out:
# ID,Mountain Peak,Mountain Range,Elevation_ft,fourteener,Prominence_ft,Isolation_mi,Lat,Long,Standard Route,Distance_mi,Elevation Gain_ft,Difficulty,Traffic Low,Traffic High,photo
# 1,Mount Elbert,Sawatch Range,14440,Y,9093,670,39.1178,-106.4454,Northeast Ridge�,9.5,4700,Class 1,20000,25000,https://www.14ers.com/photos/mtelbert/peakphotos/large/201207_Elbert01.jpg
# 2,Mount Massive,Sawatch Range,14428,Y,1961,5.06,39.1875,-106.4757,East Slopes�,14.5,4500,Class 2,7000,10000,https://www.14ers.com/photos/mtmassive/peakphotos/large/200508_Massive01.jpg
# 3,Mount Harvard,Sawatch Range,14421,Y,2360,14.93,38.9244,-106.3207,South Slopes�,14,4600,Class 2,5000,7000,https://www.14ers.com/photos/harvardgroup/peakphotos/large/200706_Harv01.jpg
# 4,Blanca Peak,Sangre de Cristo Range,14351,Y,5326,103.4,37.5775,-105.4856,Northwest Ridge�,17,6500,Hard Class 2,1000,3000,https://www.14ers.com/photos/blancagroup/peakphotos/large/200607_Blanca01.jpg

# %%
import pyowm

owm = pyowm.OWM('6b7bc44a4580ee3a51e0b787610a87e7')  # You MUST provide a valid API key
# Search current weather observations in the surroundings of
# lat=22.57W, lon=43.12S (Rio de Janeiro, BR)
weather = owm.weather_at_coords(-22.57, -43.12)

# %%
#CSV CLEAN FOR API USAGE 
Mountain_lat_long_df = df_mountain[['Mountain Peak', 'Lat', 'Long','photo','Elevation_ft','Prominence_ft','Difficulty','Standard Route','Distance_mi','Elevation Gain_ft']]



display(Mountain_lat_long_df.set_index('Mountain Peak').head(5).style.set_properties(**{"background-color":"grey","color":"black","border-color":"white"}))
# # # Output File (CSV)
# # output_data_file = "14er.csv"


Mountain_lat_long_df.to_csv('Mountain.csv', index=False)
# # Range of latitudes and longitudes
# lat_range = (-90, 90)
# lng_range = (-180, 180)
# Out:
# <style  type="text/css" >
#     #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col0 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col1 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col2 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col3 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col4 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_a393c200_c68b_11e9_a5da_2cf0ee134bbcrow0_col5 {
#             background-color:  grey;
# ...

# %% [markdown]
# ## WEATHER API

# %%
Mountain_lat_long_df['weather_json'] = Mountain_lat_long_df\
    .apply(lambda row: json.loads(owm.weather_at_coords(row.Lat, row.Long).to_JSON()), axis=1)

pd.options.display.max_colwidth = 100
Mountain_lat_long_df.head()
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#    Mountain Peak      Lat      Long  \
# 0   Mount Elbert  39.1178 -106.4454
# 1  Mount Massive  39.1875 -106.4757
# 2  Mount Harvard  38.9244 -106.3207
# 3    Blanca Peak  37.5775 -105.4856
# 4  La Plata Peak  39.0294 -106.4729
#
#                                                                            photo  \
# 0     https://www.14ers.com/photos/mtelbert/peakphotos/large/201207_Elbert01.jpg
# 1   https://www.14ers.com/photos/mtmassive/peakphotos/large/200508_Massive01.jpg
# 2   https://www.14ers.com/photos/harvardgroup/peakphotos/large/200706_Harv01.jpg
# ...

# %%
#Get column name in dataframe 

Mountain_lat_long_df.iloc[0].weather_json


Mountain_lat_long_df['Max Temp'] = Mountain_lat_long_df.weather_json.map(lambda x: x.get('Weather').get('temperature').get('temp_max'))
Mountain_lat_long_df['Min Temp'] = Mountain_lat_long_df.weather_json.map(lambda x: x.get('Weather').get('temperature').get('temp_min'))
Mountain_lat_long_df['Snow'] = Mountain_lat_long_df.weather_json.map(lambda x: x.get('Weather').get('snow'))
Mountain_lat_long_df['WindSpeed'] = Mountain_lat_long_df.weather_json.map(lambda x: x.get('Weather').get('wind').get('speed'))
Mountain_lat_long_df['Clouds'] = Mountain_lat_long_df.weather_json.map(lambda x: x.get('Weather').get('clouds'))

Mountain_lat_long_df.head()
# Out:
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   import sys
# /Users/admin/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
weather_df = Mountain_lat_long_df[['Mountain Peak', 'Lat','Long','Max Temp','Min Temp','Snow','WindSpeed','Clouds']]

# %%
display(weather_df.set_index('Mountain Peak').head(5).style.set_properties(**{"background-color":"grey","color":"black","border-color":"white"}))
# Out:
# <style  type="text/css" >
#     #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col0 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col1 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col2 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col3 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col4 {
#             background-color:  grey;
#             color:  black;
#             border-color:  white;
#         }    #T_7484f314_c689_11e9_a5da_2cf0ee134bbcrow0_col5 {
#             background-color:  grey;
# ...

# %%
weather_df.to_csv('Weather.csv', index=False)

# %%
Mountain_lat_long_df.iloc[0].weather_json.get('Weather').get('sunset_time')

# str object has no attriute keys -- literally json from the API
# the API did NOT convert it to a dictionary
# Out:
# 1566525144

# %%
# !pip install pyowm

# %%
weather.to_JSON()
# Out:
# '{"reception_time": 1566523808, "Location": {"name": "Inhomirim", "coordinates": {"lon": -43.12, "lat": -22.57}, "ID": 3461200, "country": "BR"}, "Weather": {"reference_time": 1566523546, "sunset_time": 1566506360, "sunrise_time": 1566465116, "clouds": 90, "rain": {}, "snow": {}, "wind": {"speed": 4.1, "deg": 60}, "humidity": 88, "pressure": {"press": 1024, "sea_level": null}, "temperature": {"temp": 291.68, "temp_kf": null, "temp_max": 292.15, "temp_min": 291.15}, "status": "Clouds", "detailed_status": "overcast clouds", "weather_code": 804, "weather_icon_name": "04n", "visibility_distance": 10000, "dewpoint": null, "humidex": null, "heat_index": null}}'

# %%
## Look at data dictionary to identify columns 
import json

json.loads(Weather_df_lat_long_df.iloc[0].weather_json)
# Out:
# {'reception_time': 1566524015,
#  'Location': {'name': 'Lake County',
#   'coordinates': {'lon': -106.45, 'lat': 39.12},
#   'ID': 5427799,
#   'country': 'US'},
#  'Weather': {'reference_time': 1566524015,
#   'sunset_time': 1566525144,
#   'sunrise_time': 1566476725,
#   'clouds': 90,
#   'rain': {},
#   'snow': {},
#   'wind': {'speed': 5.7, 'deg': 280, 'gust': 11.3},
#   'humidity': 31,
#   'pressure': {'press': 1028, 'sea_level': None},
#   'temperature': {'temp': 287.92,
#    'temp_kf': None,
#    'temp_max': 291.15,
#    'temp_min': 285.93},
#   'status': 'Rain',
#   'detailed_status': 'light rain',
#   'weather_code': 500,
#   'weather_icon_name': '10n',
#   'visibility_distance': 16093,
#   'dewpoint': None,
#   'humidex': None,
#   'heat_index': None}}

# %% [markdown]
# ## SQL IMPORT OF DF

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine('postgresql+psycopg2://postgres:admin@localhost:5432/Mountain')
Mountain_lat_long_df.to_sql('ETL PROJECT', engine)
